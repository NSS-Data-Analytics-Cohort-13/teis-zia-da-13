# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
outcome_1 = pd.read_csv('../data/outcome1_a.csv')

outcome_2 = pd.read_csv('../data/outcome2_a.csv')

outcome_3 = pd.read_csv('../data/outcome3_a.csv')

pc_a = pd.concat([outcome_1, outcome_2, outcome_3], ignore_index=True)

id3 = pc_a['Student TEIDS ID']

# %%
pc_a.head()
# Out:
#    Unnamed: 0  Student TEIDS ID  USE_ENTRANCE_DQScore_Adaptive  \
# 0           6            486067                           93.0
# 1          13            490309                           88.0
# 2         502            520001                           95.0
# 3         544            522186                           60.0
# 4         613            523762                           55.0
#
#    USE_ENTRANCE_DQScore_Cognitive  USE_ENTRANCE_DQScore_Communication  \
# 0                            74.0                                75.0
# 1                            65.0                                55.0
# 2                            83.0                                65.0
# 3                            58.0                                55.0
# 4                            67.0                                55.0
#
#    USE_ENTRANCE_DQScore_Motor  USE_ENTRANCE_DQScore_Social  \
# 0                        77.0                         77.0
# 1                        66.0                         88.0
# 2                        85.0                         95.0
# 3                        73.0                         83.0
# 4                        63.0                         75.0
#
#    USE_ENTRANCE_ZScore_Adaptive  USE_ENTRANCE_ZScore_Adaptive-Self_Care  \
# 0                         -0.47                                   -1.00
# 1                         -0.80                                   -2.33
# 2                         -0.33                                   -0.33
# 3                         -2.67                                   -2.67
# 4                         -3.00                                   -3.00
#
#    USE_ENTRANCE_ZScore_Adaptive-Personal_Responsibility  ...  \
# 0                                               0.00     ...
# 1                                               0.67     ...
# 2                                              -0.33     ...
# 3                                               0.00     ...
# 4                                               0.00     ...
#
#    EXIT_Cognitive-Perception and Concepts Z-Score  \
# 0                                             1.0
# 1                                             3.0
# 2                                             3.0
# 3                                             2.0
# 4                                             3.0
#
#    EXIT_Cognitive-Perception and Concepts T-Score  \
# 0                                            40.0
# 1                                            20.0
# 2                                            20.0
# 3                                            30.0
# 4                                            20.0
#
#    EXIT_Cognitive-Perception and Concepts NCE  social_category  \
# 0                                          29                a
# 1                                          <1                a
# 2                                          <1                a
# 3                                           8                a
# 4                                          <1                a
#
#    adaptive_category  outcome2_entrance_DQ  outcome2_exit_DQ  \
# 0                  a                   NaN               NaN
# 1                  a                   NaN               NaN
# 2                  a                   NaN               NaN
# 3                  a                   NaN               NaN
# 4                  b                   NaN               NaN
#
#    outcome2_subdomain_check  outcome2_category  outcome3_category
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 2                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 4                       NaN                NaN                NaN
#
# [5 rows x 255 columns]

# %%
id3.head()
# Out:
# 0    486067
# 1    490309
# 2    520001
# 3    522186
# 4    523762
# Name: Student TEIDS ID, dtype: int64
